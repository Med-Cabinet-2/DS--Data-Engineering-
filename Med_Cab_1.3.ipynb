# %%
"""Import Statements:
"""
#base
import re
import string
import pandas as pd
import numpy as np 
from collections import Counter

# %%
# Plotting
import squarify
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA

# NLP Libraries
from spacy.tokenizer import Tokenizer
from nltk.stem import PorterStemmer

import spacy
nlp = spacy.load("en_core_web_lg")

# %%
def tokenize(text):
    """Parses a string into a list of semantic units (words)

    Args:
        text (str): The string that the function will tokenize.

    Returns:
        list: tokens parsed out by the mechanics of your choice
    """
    
    tokens = re.sub(r'[^a-zA-Z ^0-9]', '', text)
    tokens = tokens.lower().split()
    return tokens

# %%
df = pd.read_csv('./data/medcab.csv')

# %%
df.head(3)
df.shape
# Out:
# (2350, 66)

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Strain                 object
# Type                   object
# Rating                float64
# Effects                object
# Flavor                 object
# Description            object
# Ammonia_flavor         object
# Apple_flavor           object
# Apricot_flavor         object
# Berry_flavor           object
# Blue_flavor            object
# Blueberry_flavor       object
# Citrus_flavor          object
# Cheese_flavor          object
# Chemical_flavor        object
# Chestnut_flavor        object
# Diesel_flavor          object
# Earthy_flavor          object
# Flowery_flavor         object
# Fruit_flavor           object
# Grape_flavor           object
# Grapefruit_flavor      object
# Honey_flavor           object
# Lavender_flavor        object
# Lemon_flavor           object
# Mango_flavor           object
# Menthol_flavor         object
# Mint_flavor            object
# Minty_flavor           object
#                        ...
# Pungent_flavor         object
# Sage_flavor            object
# Skunk_flavor           object
# SpicyHerbal_flavor     object
# Strawberry             object
# Sweet_flavor           object
# Tea_flavor             object
# Tobacco_flavor         object
# Tree_flavor            object
# Tropical_flavor        object
# Vanilla_flavor         object
# Violet_flavor          object
# Woody_flavor           object
# Aroused_effect           bool
# Creative_effect          bool
# Energetic_effect         bool
# Euphoric_effect          bool
# Focused_effect           bool
# Giggly_effect            bool
# Happy_effect             bool
# Hungry_effect            bool
# Relaxed_effect           bool
# Sleepy_effect            bool
# Talkative_effect         bool
# Tingly_effect            bool
# Uplifted_effect          bool
# None_effect              bool
# hybrid_type              bool
# sativa_type              bool
# indica_type              bool
# Length: 66, dtype: object

# %%
df.drop(['Unnamed: 0'], axis=1).head()
# Out:
#            Strain    Type  Rating  \
# 0          100-Og  hybrid     4.0
# 1  98-White-Widow  hybrid     4.7
# 2            1024  sativa     4.4
# 3        13-Dawgs  hybrid     4.2
# 4        24K-Gold  hybrid     4.6
#
#                                           Effects  \
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed
# 1    Relaxed, Aroused, Creative, Happy, Energetic
# 2   Uplifted, Happy, Relaxed, Energetic, Creative
# 3     Tingly, Creative, Hungry, Relaxed, Uplifted
# 4   Happy, Relaxed, Euphoric, Uplifted, Talkative
#
#                         Flavor  \
# 0        Earthy, Sweet, Citrus
# 1      Flowery, Violet, Diesel
# 2    Spicy/Herbal, Sage, Woody
# 3  Apricot, Citrus, Grapefruit
# 4       Citrus, Earthy, Orange
#
#                                          Description Ammonia_flavor  \
# 0  $100 OG is a 50/50 hybrid strain that packs a ...          False
# 1  The ‘98 Aloha White Widow is an especially pot...          False
# 2  1024 is a sativa-dominant hybrid bred in Spain...          False
# 3  13 Dawgs is a hybrid of G13 and Chemdawg genet...          False
# 4  Also known as Kosher Tangie  24k Gold is a 60%...          False
#
#   Apple_flavor Apricot_flavor Berry_flavor  ... Hungry_effect Relaxed_effect  \
# 0        False          False        False  ...         False           True
# 1        False          False        False  ...         False           True
# 2        False          False        False  ...         False           True
# 3        False           True        False  ...          True           True
# 4        False          False        False  ...         False           True
#
#   Sleepy_effect Talkative_effect Tingly_effect Uplifted_effect None_effect  \
# 0         False            False          True           False       False
# 1         False            False         False           False       False
# 2         False            False         False            True       False
# 3         False            False          True            True       False
# 4         False             True         False            True       False
#
#   hybrid_type sativa_type indica_type
# 0        True       False       False
# 1        True       False       False
# 2       False        True       False
# 3        True       False       False
# 4        True       False       False
#
# [5 rows x 65 columns]

# %% [markdown]
# ### Text Features:

# %%
df['Savor'] = ', ' + df['Flavor'].astype(str)

# %%
df['Style'] = ', ' + df['Description'].astype(str)

# %%
df['Breed'] = ', ' + df['Strain'].astype(str)

# %%
df['Text'] = df['Effects'].map(str) + df['Savor']

# %%
df['Text'] = df['Text'].map(str) + df['Style']

# %%
df['Text'] = df['Text'].map(str) + df['Breed']

# %%
df['Text'] = df['Text'].map(str) + df['Style']

# %%
df['Effects_and_Flavor'] = df['Effects'].map(str) + df['Savor']

# %%
df.head(3)
# Out:
#    Unnamed: 0          Strain    Type  Rating  \
# 0           0          100-Og  hybrid     4.0
# 1           1  98-White-Widow  hybrid     4.7
# 2           2            1024  sativa     4.4
#
#                                           Effects                     Flavor  \
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed      Earthy, Sweet, Citrus
# 1    Relaxed, Aroused, Creative, Happy, Energetic    Flowery, Violet, Diesel
# 2   Uplifted, Happy, Relaxed, Energetic, Creative  Spicy/Herbal, Sage, Woody
#
#                                          Description Ammonia_flavor  \
# 0  $100 OG is a 50/50 hybrid strain that packs a ...          False
# 1  The ‘98 Aloha White Widow is an especially pot...          False
# 2  1024 is a sativa-dominant hybrid bred in Spain...          False
#
#   Apple_flavor Apricot_flavor  ... Uplifted_effect None_effect hybrid_type  \
# 0        False          False  ...           False       False        True
# 1        False          False  ...           False       False        True
# 2        False          False  ...            True       False       False
#
#   sativa_type indica_type                        Savor  \
# 0       False       False      , Earthy, Sweet, Citrus
# 1       False       False    , Flowery, Violet, Diesel
# 2        True       False  , Spicy/Herbal, Sage, Woody
#
#                                                Style             Breed  \
# 0  , $100 OG is a 50/50 hybrid strain that packs ...          , 100-Og
# 1  , The ‘98 Aloha White Widow is an especially p...  , 98-White-Widow
# 2  , 1024 is a sativa-dominant hybrid bred in Spa...            , 1024
#
#                                                 Text  \
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed...
# 1  Relaxed, Aroused, Creative, Happy, Energetic, ...
# 2  Uplifted, Happy, Relaxed, Energetic, Creative,...
#
#                                   Effects_and_Flavor
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed...
# 1  Relaxed, Aroused, Creative, Happy, Energetic, ...
# 2  Uplifted, Happy, Relaxed, Energetic, Creative,...
#
# [3 rows x 71 columns]

# %%
df = df.reset_index()

# %%
df['ID'] = df['Strain'].index
df['ID'] = df['ID'].astype(int)

# %%
df['ID'].isna().sum()
# Out:
# 0

# %%
np.random.seed(42)

# %%
df.shape
# Out:
# (2350, 73)

# %%
df['index'].nunique(), df['ID'].nunique()
# Out:
# (2350, 2350)

# %%
df['Text']= df['Text'].str.replace(',', ' ')

# %% [markdown]
# ## Vectorizing:

# %%
df.head(2)
# Out:
#    index  Unnamed: 0          Strain    Type  Rating  \
# 0      0           0          100-Og  hybrid     4.0
# 1      1           1  98-White-Widow  hybrid     4.7
#
#                                           Effects                   Flavor  \
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed    Earthy, Sweet, Citrus
# 1    Relaxed, Aroused, Creative, Happy, Energetic  Flowery, Violet, Diesel
#
#                                          Description Ammonia_flavor  \
# 0  $100 OG is a 50/50 hybrid strain that packs a ...          False
# 1  The ‘98 Aloha White Widow is an especially pot...          False
#
#   Apple_flavor  ... None_effect hybrid_type sativa_type indica_type  \
# 0        False  ...       False        True       False       False
# 1        False  ...       False        True       False       False
#
#                        Savor  \
# 0    , Earthy, Sweet, Citrus
# 1  , Flowery, Violet, Diesel
#
#                                                Style             Breed  \
# 0  , $100 OG is a 50/50 hybrid strain that packs ...          , 100-Og
# 1  , The ‘98 Aloha White Widow is an especially p...  , 98-White-Widow
#
#                                                 Text  \
# 0  Creative  Energetic  Tingly  Euphoric  Relaxed...
# 1  Relaxed  Aroused  Creative  Happy  Energetic  ...
#
#                                   Effects_and_Flavor ID
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed...  0
# 1  Relaxed, Aroused, Creative, Happy, Energetic, ...  1
#
# [2 rows x 73 columns]

# %%
df.drop(['Unnamed: 0'], axis=1).head()
# Out:
#    index          Strain    Type  Rating  \
# 0      0          100-Og  hybrid     4.0
# 1      1  98-White-Widow  hybrid     4.7
# 2      2            1024  sativa     4.4
# 3      3        13-Dawgs  hybrid     4.2
# 4      4        24K-Gold  hybrid     4.6
#
#                                           Effects  \
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed
# 1    Relaxed, Aroused, Creative, Happy, Energetic
# 2   Uplifted, Happy, Relaxed, Energetic, Creative
# 3     Tingly, Creative, Hungry, Relaxed, Uplifted
# 4   Happy, Relaxed, Euphoric, Uplifted, Talkative
#
#                         Flavor  \
# 0        Earthy, Sweet, Citrus
# 1      Flowery, Violet, Diesel
# 2    Spicy/Herbal, Sage, Woody
# 3  Apricot, Citrus, Grapefruit
# 4       Citrus, Earthy, Orange
#
#                                          Description Ammonia_flavor  \
# 0  $100 OG is a 50/50 hybrid strain that packs a ...          False
# 1  The ‘98 Aloha White Widow is an especially pot...          False
# 2  1024 is a sativa-dominant hybrid bred in Spain...          False
# 3  13 Dawgs is a hybrid of G13 and Chemdawg genet...          False
# 4  Also known as Kosher Tangie  24k Gold is a 60%...          False
#
#   Apple_flavor Apricot_flavor  ... hybrid_type sativa_type indica_type  \
# 0        False          False  ...        True       False       False
# 1        False          False  ...        True       False       False
# 2        False          False  ...       False        True       False
# 3        False           True  ...        True       False       False
# 4        False          False  ...        True       False       False
#
#                            Savor  \
# 0        , Earthy, Sweet, Citrus
# 1      , Flowery, Violet, Diesel
# 2    , Spicy/Herbal, Sage, Woody
# 3  , Apricot, Citrus, Grapefruit
# 4       , Citrus, Earthy, Orange
#
#                                                Style             Breed  \
# 0  , $100 OG is a 50/50 hybrid strain that packs ...          , 100-Og
# 1  , The ‘98 Aloha White Widow is an especially p...  , 98-White-Widow
# 2  , 1024 is a sativa-dominant hybrid bred in Spa...            , 1024
# 3  , 13 Dawgs is a hybrid of G13 and Chemdawg gen...        , 13-Dawgs
# 4  , Also known as Kosher Tangie  24k Gold is a 6...        , 24K-Gold
#
#                                                 Text  \
# 0  Creative  Energetic  Tingly  Euphoric  Relaxed...
# 1  Relaxed  Aroused  Creative  Happy  Energetic  ...
# 2  Uplifted  Happy  Relaxed  Energetic  Creative ...
# 3  Tingly  Creative  Hungry  Relaxed  Uplifted  A...
# 4  Happy  Relaxed  Euphoric  Uplifted  Talkative ...
#
#                                   Effects_and_Flavor ID  \
# 0  Creative, Energetic, Tingly, Euphoric, Relaxed...  0
# 1  Relaxed, Aroused, Creative, Happy, Energetic, ...  1
# 2  Uplifted, Happy, Relaxed, Energetic, Creative,...  2
# 3  Tingly, Creative, Hungry, Relaxed, Uplifted, A...  3
# 4  Happy, Relaxed, Euphoric, Uplifted, Talkative,...  4
#
#                                               tokens
# 0  [creative,  , energetic,  , tingly,  , euphori...
# 1  [relaxed,  , aroused,  , creative,  , happy,  ...
# 2  [uplifted,  , happy,  , relaxed,  , energetic,...
# 3  [tingly,  , creative,  , hungry,  , relaxed,  ...
# 4  [happy,  , relaxed,  , euphoric,  , uplifted, ...
#
# [5 rows x 73 columns]

# %%
# possible analysis functions

def count(docs):

        word_counts = Counter()
        appears_in = Counter()
        
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %%
#Tokenizer
tokenizer = Tokenizer(nlp.vocab)

# %%
#Tokenizer Pipe

tokens = []

""" Make them tokens """
for doc in tokenizer.pipe(df['Text'], batch_size=100):
    doc_tokens = [token.text for token in doc]
    tokens.append(doc_tokens)

df['tokens'] = tokens

# %%
# Using the "Count" function
wc = count(df['tokens'])

# %%
wc = count(df['tokens'])
wc.head(3)
# Out:
#    word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 15             2350  39608   1.0   0.097077       0.097077        1.000000
# 66  and        2231  14650   2.0   0.035906       0.132984        0.949362
# 13    a        2187  12238   3.0   0.029995       0.162978        0.930638

# %%
wc_top20 = wc[wc['rank'] <= 30]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8)
plt.axis('off')
plt.show()

# %%
# Object from Base Python
from collections import Counter

# The object `Counter` takes an iterable, but you can instaniate an empty one and update it. 
word_counts = Counter()

# Update it based on a split of each of our documents
df['tokens'].apply(lambda x: word_counts.update(x))

# Print out the 10 most common words
word_counts.most_common(10)
# Out:
# [(' ', 39608),
#  ('and', 14650),
#  ('a', 12238),
#  ('the', 9642),
#  ('of', 9130),
#  ('is', 7700),
#  ('to', 5902),
#  ('with', 5336),
#  ('strain', 4672),
#  ('that', 4536)]

# %%
tokens = []

""" Update those tokens w/o stopwords"""
for doc in tokenizer.pipe(df['Text'], batch_size=100):
    
    doc_tokens = []
    
    for token in doc:
        if (token.is_stop == False) & (token.is_punct == False):
            doc_tokens.append(token.text.lower())

    tokens.append(doc_tokens)

df['tokens'] = tokens

# %%
wc = count(df['tokens'])

# %%
wc = count(df['tokens'])
wc.head()
# Out:
#         word  appears_in  count  rank  pct_total  cul_pct_total  \
# 7                   2350  39608   1.0   0.143795       0.143795
# 35    strain        1598   4680   2.0   0.016991       0.160786
# 70                  1153   3631   3.0   0.013182       0.173968
# 26     sweet        1379   2650   4.0   0.009621       0.183589
# 155  effects        1035   2430   5.0   0.008822       0.192411
#
#      appears_in_pct
# 7          1.000000
# 35         0.680000
# 70         0.490638
# 26         0.586809
# 155        0.440426

# %%
wc_top20 = wc[wc['rank'] <= 30]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8)
plt.axis('off')
plt.show()

# %%
wc.head(25)
# Out:
#                 word  appears_in  count  rank  pct_total  cul_pct_total  \
# 7                           2350  39608   1.0   0.143795       0.143795
# 35            strain        1598   4680   2.0   0.016991       0.160786
# 70                          1153   3631   3.0   0.013182       0.173968
# 26             sweet        1379   2650   4.0   0.009621       0.183589
# 155          effects        1035   2430   5.0   0.008822       0.192411
# 32            hybrid        1028   2362   6.0   0.008575       0.200986
# 92             happy        1891   2118   7.0   0.007689       0.208675
# 25          euphoric        1679   1998   8.0   0.007254       0.215929
# 34                og         466   1944   9.0   0.007058       0.222987
# 23           relaxed        1735   1859  10.0   0.006749       0.229736
# 40            earthy        1248   1858  11.0   0.006745       0.236481
# 200             kush         512   1756  12.0   0.006375       0.242856
# 144         uplifted        1519   1571  13.0   0.005703       0.248560
# 233            cross         727   1502  14.0   0.005453       0.254013
# 44            indica         584   1500  15.0   0.005446       0.259458
# 198            aroma         718   1474  16.0   0.005351       0.264810
# 11            sativa         461   1180  17.0   0.004284       0.269094
# 21            citrus         667   1152  18.0   0.004182       0.273276
# 28              buds         525   1112  19.0   0.004037       0.277313
# 37              body         505   1072  20.0   0.003892       0.281205
# 114         genetics         481   1042  21.0   0.003783       0.284988
# 182  indica-dominant         515   1040  22.0   0.003776       0.288763
# 396           purple         299   1032  23.0   0.003747       0.292510
# 38          creative         817   1019  24.0   0.003699       0.296209
# 112          pungent         641    991  25.0   0.003598       0.299807
#
#      appears_in_pct
# 7          1.000000
# 35         0.680000
# 70         0.490638
# 26         0.586809
# 155        0.440426
# 32         0.437447
# 92         0.804681
# 25         0.714468
# 34         0.198298
# 23         0.738298
# 40         0.531064
# 200        0.217872
# 144        0.646383
# 233        0.309362
# 44         0.248511
# 198        0.305532
# 11         0.196170
# 21         0.283830
# 28         0.223404
# 37         0.214894
# 114        0.204681
# 182        0.219149
# 396        0.127234
# 38         0.347660
# 112        0.272766

# %%
wc.tail(25)
# Out:
#                        word  appears_in  count     rank  pct_total  \
# 14008         wild-thailand           1      1  14140.0   0.000004
# 14013         willie-nelson           1      1  14141.0   0.000004
# 14015           willy-wonka           1      1  14142.0   0.000004
# 14018         willys-wonder           1      1  14143.0   0.000004
# 14019           wonder-haze           1      1  14144.0   0.000004
# 14028            wonder-kid           1      1  14145.0   0.000004
# 14034          wonder-woman           1      1  14146.0   0.000004
# 14035        wonderwoman-og           1      1  14147.0   0.000004
# 14037  wonka-s-bubbilicious           1      1  14148.0   0.000004
# 14042            woody-kush           1      1  14149.0   0.000004
# 14055                x-file           1      1  14150.0   0.000004
# 14064             x-tra-chz           1      1  14151.0   0.000004
# 14070               xxx-420           1      1  14152.0   0.000004
# 14079                xxx-og           1      1  14153.0   0.000004
# 14095              y-griega           1      1  14154.0   0.000004
# 14102               yeti-og           1      1  14155.0   0.000004
# 14103               yoda-og           1      1  14156.0   0.000004
# 14107           yodas-brain           1      1  14157.0   0.000004
# 14110           yogi-diesel           1      1  14158.0   0.000004
# 14118           zellys-gift           1      1  14159.0   0.000004
# 14129             zeta-sage           1      1  14160.0   0.000004
# 14133               zeus-og           1      1  14161.0   0.000004
# 14140           zombie-kush           1      1  14162.0   0.000004
# 14152             zombie-og           1      1  14163.0   0.000004
# 14155              zoom-pie           1      1  14164.0   0.000004
#
#        cul_pct_total  appears_in_pct
# 14008       0.999913        0.000426
# 14013       0.999916        0.000426
# 14015       0.999920        0.000426
# 14018       0.999924        0.000426
# 14019       0.999927        0.000426
# 14028       0.999931        0.000426
# 14034       0.999935        0.000426
# 14035       0.999938        0.000426
# 14037       0.999942        0.000426
# 14042       0.999946        0.000426
# 14055       0.999949        0.000426
# 14064       0.999953        0.000426
# 14070       0.999956        0.000426
# 14079       0.999960        0.000426
# 14095       0.999964        0.000426
# 14102       0.999967        0.000426
# 14103       0.999971        0.000426
# 14107       0.999975        0.000426
# 14110       0.999978        0.000426
# 14118       0.999982        0.000426
# 14129       0.999985        0.000426
# 14133       0.999989        0.000426
# 14140       0.999993        0.000426
# 14152       0.999996        0.000426
# 14155       1.000000        0.000426

# %%
# Spacy's Default stop words:
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
wc = count(df['tokens'])
wc.head(50)
# Out:
#                 word  appears_in  count  rank  pct_total  cul_pct_total  \
# 7                           2350  39608   1.0   0.143795       0.143795
# 35            strain        1598   4680   2.0   0.016991       0.160786
# 70                          1153   3631   3.0   0.013182       0.173968
# 26             sweet        1379   2650   4.0   0.009621       0.183589
# 155          effects        1035   2430   5.0   0.008822       0.192411
# 32            hybrid        1028   2362   6.0   0.008575       0.200986
# 92             happy        1891   2118   7.0   0.007689       0.208675
# 25          euphoric        1679   1998   8.0   0.007254       0.215929
# 34                og         466   1944   9.0   0.007058       0.222987
# 23           relaxed        1735   1859  10.0   0.006749       0.229736
# 40            earthy        1248   1858  11.0   0.006745       0.236481
# 200             kush         512   1756  12.0   0.006375       0.242856
# 144         uplifted        1519   1571  13.0   0.005703       0.248560
# 233            cross         727   1502  14.0   0.005453       0.254013
# 44            indica         584   1500  15.0   0.005446       0.259458
# 198            aroma         718   1474  16.0   0.005351       0.264810
# 11            sativa         461   1180  17.0   0.004284       0.269094
# 21            citrus         667   1152  18.0   0.004182       0.273276
# 28              buds         525   1112  19.0   0.004037       0.277313
# 37              body         505   1072  20.0   0.003892       0.281205
# 114         genetics         481   1042  21.0   0.003783       0.284988
# 182  indica-dominant         515   1040  22.0   0.003776       0.288763
# 396           purple         299   1032  23.0   0.003747       0.292510
# 38          creative         817   1019  24.0   0.003699       0.296209
# 112          pungent         641    991  25.0   0.003598       0.299807
# 140             bred         472    974  26.0   0.003536       0.303343
# 256             sour         296    950  27.0   0.003449       0.306792
# 98            diesel         345    932  28.0   0.003384       0.310176
# 322         cannabis         435    932  29.0   0.003384       0.313559
# 39              high         398    914  30.0   0.003318       0.316878
# 0               pain         433    890  31.0   0.003231       0.320109
# 117            seeds         405    856  32.0   0.003108       0.323216
# 12         energetic         686    832  33.0   0.003021       0.326237
# 971             haze         211    809  34.0   0.002937       0.329174
# 49            potent         386    792  35.0   0.002875       0.332049
# 120  sativa-dominant         394    790  36.0   0.002868       0.334917
# 411           sleepy         741    781  37.0   0.002835       0.337753
# 81             skunk         327    772  38.0   0.002803       0.340556
# 175            known         350    744  39.0   0.002701       0.343257
# 729            lemon         301    744  40.0   0.002701       0.345958
# 562            berry         433    729  41.0   0.002647       0.348604
# 50             white         207    704  42.0   0.002556       0.351160
# 387             pine         423    700  43.0   0.002541       0.353701
# 164          focused         620    695  44.0   0.002523       0.356225
# 24            strong         305    670  45.0   0.002432       0.358657
# 36             green         269    666  46.0   0.002418       0.361075
# 406             blue         187    657  47.0   0.002385       0.363460
# 17          cerebral         325    656  48.0   0.002382       0.365842
# 213           flavor         318    656  49.0   0.002382       0.368223
# 128        uplifting         313    644  50.0   0.002338       0.370561
#
#      appears_in_pct
# 7          1.000000
# 35         0.680000
# 70         0.490638
# 26         0.586809
# 155        0.440426
# 32         0.437447
# 92         0.804681
# 25         0.714468
# 34         0.198298
# 23         0.738298
# 40         0.531064
# 200        0.217872
# 144        0.646383
# 233        0.309362
# 44         0.248511
# 198        0.305532
# 11         0.196170
# 21         0.283830
# 28         0.223404
# 37         0.214894
# 114        0.204681
# 182        0.219149
# 396        0.127234
# 38         0.347660
# 112        0.272766
# 140        0.200851
# 256        0.125957
# 98         0.146809
# 322        0.185106
# 39         0.169362
# 0          0.184255
# 117        0.172340
# 12         0.291915
# 971        0.089787
# 49         0.164255
# 120        0.167660
# 411        0.315319
# 81         0.139149
# 175        0.148936
# 729        0.128085
# 562        0.184255
# 50         0.088085
# 387        0.180000
# 164        0.263830
# 24         0.129787
# 36         0.114468
# 406        0.079574
# 17         0.138298
# 213        0.135319
# 128        0.133191
